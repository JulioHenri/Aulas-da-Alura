# %%
import pandas as pd
dataset = pd.read_csv('db.csv', sep=';')
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset.dtypes
# Out:
# Nome              object
# Motor             object
# Ano                int64
# Quilometragem    float64
# Zero_km             bool
# Acessórios        object
# Valor            float64
# dtype: object

# %%
dataset[['Quilometragem','Valor']].describe()
# Out:
#        Quilometragem          Valor
# count     197.000000     258.000000
# mean    58278.421320   98960.513101
# std     35836.733259   29811.932305
# min       107.000000   50742.100000
# 25%     27505.000000   70743.512500
# 50%     55083.000000   97724.380000
# 75%     90495.000000  124633.302500
# max    119945.000000  149489.920000

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           258 non-null    object
#  1   Motor          258 non-null    object
#  2   Ano            258 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        258 non-null    bool
#  5   Acessórios     258 non-null    object
#  6   Valor          258 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 12.5+ KB

# %%
#criar tupla
nomes_carros = ('ferrari','jetta','bmw')
nomes_carros
# Out:
# ('ferrari', 'jetta', 'bmw')

# %%
for item in nomes_carros:
    print(item)
# Out:
# ferrari
# jetta
# bmw

# %%
carro_1, carro_2, carro_3 = nomes_carros
carro_1
# Out:
# 'ferrari'

# %%
_, a, *_ = nomes_carros
a
# Out:
# 'jetta'

# %%
valor = 124124, 1242112, 123123

# %%
list(zip(nomes_carros, valor))
# Out:
# [('ferrari', 124124), ('jetta', 1242112), ('bmw', 123123)]

# %%
for carros, valores in zip(nomes_carros, valor):
    print(carros, valores)
# Out:
# ferrari 124124
# jetta 1242112
# bmw 123123

# %%
for carros, valores in zip(nomes_carros, valor):
    if(valores>134142):
        print(carros)
# Out:
# jetta

# %%
data = {'ferrari': 13423,'jetta':24234234,'bmw':634523}
data
# Out:
# {'ferrari': 13423, 'jetta': 24234234, 'bmw': 634523}

# %%
data['ferrari']
# Out:
# 13423

# %%
'ferrari' in data
# Out:
# True

# %%
'fusca' in data
# Out:
# False

# %%
len(data)
# Out:
# 3

# %%
#adicionar
data['porsche'] = 324234
data
# Out:
# {'ferrari': 13423, 'jetta': 24234234, 'bmw': 634523, 'porsche': 324234}

# %%
#excluir

del data['ferrari']
data
# Out:
# {'jetta': 24234234, 'bmw': 634523, 'porsche': 324234}

# %%
data.update({'ferrari' : 1341234})
data
# Out:
# {'jetta': 24234234, 'bmw': 634523, 'porsche': 324234, 'ferrari': 1341234}

# %%
data.pop('fusca', 'Chave não encontrada')
# Out:
# 'Chave não encontrada'

# %%
data.clear()
data
# Out:
# {}

# %%
data = {'ferrari': 13423,'jetta':24234234,'bmw':634523}
data
# Out:
# {'ferrari': 13423, 'jetta': 24234234, 'bmw': 634523}

# %%
data.keys()
# Out:
# dict_keys(['ferrari', 'jetta', 'bmw'])

# %%
for key in data.keys():
    print(data[key])
# Out:
# 13423
# 24234234
# 634523

# %%
data.values()
# Out:
# dict_values([13423, 24234234, 634523])

# %%
data.items()
# Out:
# dict_items([('ferrari', 13423), ('jetta', 24234234), ('bmw', 634523)])

# %%
for item in data.items():
    print(item)
# Out:
# ('ferrari', 13423)
# ('jetta', 24234234)
# ('bmw', 634523)

# %%
for key, value in data.items():
    print(key, value)
# Out:
# ferrari 13423
# jetta 24234234
# bmw 634523

# %%
for key, value in data.items():
    if(value > 100000):
        print(key)
# Out:
# jetta
# bmw

# %%
list(data.values())
# Out:
# [13423, 24234234, 634523]

# %%
sum(data.values())
# Out:
# 24882180

# %%
zip?
#zip é um iterador de tuplas

# %%
#definindo funções sem e com parâmetros
#funções sem parâmetro

def media():
    valor = (1 + 2 + 3) / 3
    print(valor)

# %%
media()
# Out:
# 2.0

# %%
#funções com parâmetros que é útil de fato

def media(numero1, numero2, numero3):
    valor = (numero1 + numero2 + numero3) / 3
    print(valor)

# %%
media(1, 2, 3)
# Out:
# 2.0

# %%
media(124,412,23)
# Out:
# 186.33333333333334

# %%
def media(lista):
    valor = sum(lista) / len(lista)
    print(valor)

# %%
media([1,2,3,4,5,6,7,8,9])
# Out:
# 5.0

# %%
#atividade
dados = {
    'Crossfox': {'km': 35000, 'ano': 2005}, 
    'DS5': {'km': 17000, 'ano': 2015}, 
    'Fusca': {'km': 130000, 'ano': 1979}, 
    'Jetta': {'km': 56000, 'ano': 2011}, 
    'Passat': {'km': 62000, 'ano': 1999}
}

# %%
def km_media(dataset, ano_atual):
    for item in dataset.items():
        resultado = item[1]['km'] / (ano_atual - item[1]['ano'])
        return (resultado, (ano_atual - item[1]['ano']))

# %%
km_media(dados, 2020)
# Out:
# (2333.3333333333335, 15)

# %%
deucerto = km_media(dados, 2020)

# %%
deucerto
# Out:
# (2333.3333333333335, 15)

# %%
#separando para não cair numa tupla
resultado, tamanho = km_media(dados, 2020)

# %%
resultado
# Out:
# 2333.3333333333335

# %%
tamanho
# Out:
# 15

# %%
result = {}

# %%
result.update({'tois' : 214})

# %%
result
# Out:
# {'tois': 214}

# %%
import pandas as pd
dataset = pd.read_csv('db.csv', sep=';')
dataset.head()
# Out:
#                Nome            Motor   Ano  Quilometragem  Zero_km  \
# 0     Jetta Variant  Motor 4.0 Turbo  2003        44410.0    False
# 1            Passat     Motor Diesel  1991         5712.0    False
# 2          Crossfox  Motor Diesel V8  1990        37123.0    False
# 3               DS5  Motor 2.4 Turbo  2019            NaN     True
# 4  Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                           Acessórios      Valor
# 0  ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# 1  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# 2  ['Piloto automático', 'Controle de estabilidad...   72832.16
# 3  ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# 4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
#excluir o index numérico 

dataset = pd.read_csv('db.csv', sep=';', index_col = 0)
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
dataset = pd.read_csv('db.csv', sep=';')
dataset['Valor']
# Out:
# 0       88078.64
# 1      106161.94
# 2       72832.16
# 3      124549.07
# 4       92612.10
#          ...
# 253     51759.58
# 254     51667.06
# 255     68934.03
# 256    122110.90
# 257     90381.47
# Name: Valor, Length: 258, dtype: float64

# %%
type(dataset['Valor'])
# Out:
# pandas.core.series.Series

# %%
dataset[['Valor']]
# Out:
#          Valor
# 0     88078.64
# 1    106161.94
# 2     72832.16
# 3    124549.07
# 4     92612.10
# ..         ...
# 253   51759.58
# 254   51667.06
# 255   68934.03
# 256  122110.90
# 257   90381.47
#
# [258 rows x 1 columns]

# %%
type(dataset[['Valor']])
# Out:
# pandas.core.frame.DataFrame

# %%
dataset = pd.read_csv('db.csv', sep=';', index_col = 0)
dataset.head()
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant     Motor 4.0 Turbo  2003        44410.0    False
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Jetta Variant     ['Rodas de liga', 'Travas elétricas', 'Piloto ...   88078.64
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
dataset.loc['Passat']
# Out:
# Motor                                                 Motor Diesel
# Ano                                                           1991
# Quilometragem                                                 5712
# Zero_km                                                      False
# Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
# Valor                                                       106162
# Name: Passat, dtype: object

# %%
#em forma de Data frame
dataset.loc[['Passat', 'DS5']]
# Out:
#                   Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat     Motor Diesel  1991         5712.0    False
# DS5     Motor 2.4 Turbo  2019            NaN     True
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# DS5     ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
#separar por linha e coluna específica
dataset.loc[['Passat', 'DS5'], ['Motor', 'Valor']]
# Out:
#                   Motor      Valor
# Nome
# Passat     Motor Diesel  106161.94
# DS5     Motor 2.4 Turbo  124549.07

# %%
#selecionar todas as linhas e colunas específicas
dataset.loc[:, ['Motor', 'Valor']].head()
# Out:
#                             Motor      Valor
# Nome
# Jetta Variant     Motor 4.0 Turbo   88078.64
# Passat               Motor Diesel  106161.94
# Crossfox          Motor Diesel V8   72832.16
# DS5               Motor 2.4 Turbo  124549.07
# Aston Martin DB4  Motor 2.4 Turbo   92612.10

# %%
#selecionar passat pelo índice
dataset.iloc[[1]]
# Out:
#                Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat  Motor Diesel  1991         5712.0    False
#
#                                                Acessórios      Valor
# Nome
# Passat  ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94

# %%
dataset.iloc[1:4]
# Out:
#                     Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat       Motor Diesel  1991         5712.0    False
# Crossfox  Motor Diesel V8  1990        37123.0    False
# DS5       Motor 2.4 Turbo  2019            NaN     True
#
#                                                  Acessórios      Valor
# Nome
# Passat    ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox  ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5       ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07

# %%
dataset.iloc[1:4, [0, 5, 2]]
# Out:
#                     Motor      Valor  Quilometragem
# Nome
# Passat       Motor Diesel  106161.94         5712.0
# Crossfox  Motor Diesel V8   72832.16        37123.0
# DS5       Motor 2.4 Turbo  124549.07            NaN

# %%
dataset.iloc[1:5, :]
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat               Motor Diesel  1991         5712.0    False
# Crossfox          Motor Diesel V8  1990        37123.0    False
# DS5               Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4  Motor 2.4 Turbo  2006        25757.0    False
#
#                                                          Acessórios      Valor
# Nome
# Passat            ['Central multimídia', 'Teto panorâmico', 'Fre...  106161.94
# Crossfox          ['Piloto automático', 'Controle de estabilidad...   72832.16
# DS5               ['Travas elétricas', '4 X 4', 'Vidros elétrico...  124549.07
# Aston Martin DB4  ['Rodas de liga', '4 X 4', 'Central multimídia...   92612.10

# %%
#fazendo queries com DataFrames, são consultas ou seleções no Df

dataset.Motor
# Out:
# Nome
# Jetta Variant                  Motor 4.0 Turbo
# Passat                            Motor Diesel
# Crossfox                       Motor Diesel V8
# DS5                            Motor 2.4 Turbo
# Aston Martin DB4               Motor 2.4 Turbo
#                                  ...
# Phantom 2013                          Motor V8
# Cadillac Ciel concept                 Motor V8
# Classe GLK               Motor 5.0 V8 Bi-Turbo
# Aston Martin DB5                  Motor Diesel
# Macan                          Motor Diesel V6
# Name: Motor, Length: 258, dtype: object

# %%
#retorna Series booleanas
motor_diesel = dataset.Motor == 'Motor Diesel'

# %%
type(motor_diesel)
# Out:
# pandas.core.series.Series

# %%
#retorna um Df só com os que tem Motor Diesel
dataset[motor_diesel]
# Out:
#                               Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Passat                 Motor Diesel  1991         5712.0    False
# Effa Hafei Picape Baú  Motor Diesel  1991       102959.0    False
# Sorento                Motor Diesel  2019            NaN     True
# New Fiesta Hatch       Motor Diesel  2017       118895.0    False
# Kangoo Express         Motor Diesel  2007        29132.0    False
# Fit                    Motor Diesel  2013        44329.0    False
# Cielo Hatch            Motor Diesel  2019            NaN     True
# Symbol                 Motor Diesel  2016       117714.0    False
# A4 Sedan               Motor Diesel  2002        30511.0    False
# A4 Avant               Motor Diesel  2014        17357.0    False
# Silver Shadow          Motor Diesel  2015        99052.0    False
# Camry                  Motor Diesel  2019            NaN     True
# Clio                   Motor Diesel  1990        66437.0    False
# ...

# %%
#selecionar por dois parâmetros agora

dataset[(dataset.Motor == 'Motor Diesel') & (dataset.Zero_km ==True)]
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Sorento              Motor Diesel  2019            NaN     True
# Cielo Hatch          Motor Diesel  2019            NaN     True
# Camry                Motor Diesel  2019            NaN     True
# Aston Martin Virage  Motor Diesel  2019            NaN     True
# Série 7 Sedã         Motor Diesel  2019            NaN     True
#
#                                                             Acessórios  \
# Nome
# Sorento              ['Sensor de chuva', 'Câmera de estacionamento'...
# Cielo Hatch          ['Painel digital', 'Central multimídia', 'Câme...
# Camry                ['Travas elétricas', 'Rodas de liga', 'Sensor ...
# Aston Martin Virage  ['Travas elétricas', 'Controle de tração', 'Câ...
# Série 7 Sedã         ['Vidros elétricos', 'Travas elétricas', 'Roda...
#
#                          Valor
# Nome
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %%
#é do tipo Series booleanas
(dataset.Motor == 'Motor Diesel') & (dataset.Zero_km ==True)
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                      False
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Length: 258, dtype: bool

# %%
#outra maneira de selecionar valores das colunas
dataset.query('Motor == "Motor Diesel" and Zero_km == True')
# Out:
#                             Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Sorento              Motor Diesel  2019            NaN     True
# Cielo Hatch          Motor Diesel  2019            NaN     True
# Camry                Motor Diesel  2019            NaN     True
# Aston Martin Virage  Motor Diesel  2019            NaN     True
# Série 7 Sedã         Motor Diesel  2019            NaN     True
#
#                                                             Acessórios  \
# Nome
# Sorento              ['Sensor de chuva', 'Câmera de estacionamento'...
# Cielo Hatch          ['Painel digital', 'Central multimídia', 'Câme...
# Camry                ['Travas elétricas', 'Rodas de liga', 'Sensor ...
# Aston Martin Virage  ['Travas elétricas', 'Controle de tração', 'Câ...
# Série 7 Sedã         ['Vidros elétricos', 'Travas elétricas', 'Roda...
#
#                          Valor
# Nome
# Sorento               81399.35
# Cielo Hatch          145197.70
# Camry                138597.27
# ...

# %%
#desempenho não tão bom

for item in dataset:
    print(item)
# Out:
# Motor
# Ano
# Quilometragem
# Zero_km
# Acessórios
# Valor

# %%
#lista com tuplas e dentro da tupla tem o índice do df e 
#uma Series contendo as informações da linha
list(dataset.iterrows())
# Out:
# [('Jetta Variant',
#   Motor                                              Motor 4.0 Turbo
#   Ano                                                           2003
#   Quilometragem                                                44410
#   Zero_km                                                      False
#   Acessórios       ['Rodas de liga', 'Travas elétricas', 'Piloto ...
#   Valor                                                      88078.6
#   Name: Jetta Variant, dtype: object),
#  ('Passat',
#   Motor                                                 Motor Diesel
#   Ano                                                           1991
#   Quilometragem                                                 5712
#   Zero_km                                                      False
#   Acessórios       ['Central multimídia', 'Teto panorâmico', 'Fre...
#   Valor                                                       106162
#   Name: Passat, dtype: object),
#  ('Crossfox',
# ...

# %%
for indice, linha in dataset.iterrows():
    if(2020 - linha['Ano'] != 0):
        dataset.loc[indice, 'km_media'] = linha['Quilometragem'] / 2020 - linha['Ano']
    else:
        dataset.loc[indice, 'km_media'] = 0
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            NaN     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
#tratamento de dados

dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 258 entries, Jetta Variant to Macan
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Motor          258 non-null    object
#  1   Ano            258 non-null    int64
#  2   Quilometragem  197 non-null    float64
#  3   Zero_km        258 non-null    bool
#  4   Acessórios     258 non-null    object
#  5   Valor          258 non-null    float64
#  6   km_media       197 non-null    float64
# dtypes: bool(1), float64(3), int64(1), object(2)
# memory usage: 24.4+ KB

# %%
#verificar quem é nulo e quem não é 
dataset.Quilometragem.isna()
# Out:
# Nome
# Jetta Variant            False
# Passat                   False
# Crossfox                 False
# DS5                       True
# Aston Martin DB4         False
#                          ...
# Phantom 2013             False
# Cadillac Ciel concept    False
# Classe GLK               False
# Aston Martin DB5         False
# Macan                    False
# Name: Quilometragem, Length: 258, dtype: bool

# %%
dataset[dataset.Quilometragem.isna()]
# Out:
#                                 Motor   Ano  Quilometragem  Zero_km  \
# Nome
# DS5                   Motor 2.4 Turbo  2019            NaN     True
# A5                    Motor 4.0 Turbo  2019            NaN     True
# J5                           Motor V6  2019            NaN     True
# A3                       Motor 1.0 8v  2019            NaN     True
# Série 1 M                    Motor V8  2019            NaN     True
# ...                               ...   ...            ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019            NaN     True
# Benni Mini                   Motor V8  2019            NaN     True
# Uno                   Motor Diesel V6  2019            NaN     True
# Santa Fe                Motor 3.0 32v  2019            NaN     True
# XC60                  Motor 4.0 Turbo  2019            NaN     True
#
#                                                              Acessórios  \
# Nome
# ...

# %%
#preencher o valor Nan com o valor 0 e atualizar o dataset
dataset.fillna(0, inplace = True)
dataset
# Out:
#                                        Motor   Ano  Quilometragem  Zero_km  \
# Nome
# Jetta Variant                Motor 4.0 Turbo  2003        44410.0    False
# Passat                          Motor Diesel  1991         5712.0    False
# Crossfox                     Motor Diesel V8  1990        37123.0    False
# DS5                          Motor 2.4 Turbo  2019            0.0     True
# Aston Martin DB4             Motor 2.4 Turbo  2006        25757.0    False
# ...                                      ...   ...            ...      ...
# Phantom 2013                        Motor V8  2014        27505.0    False
# Cadillac Ciel concept               Motor V8  1991        29981.0    False
# Classe GLK             Motor 5.0 V8 Bi-Turbo  2002        52637.0    False
# Aston Martin DB5                Motor Diesel  1996         7685.0    False
# Macan                        Motor Diesel V6  1992        50188.0    False
#
# ...

# %%
dataset.query('Zero_km == True')
# Out:
#                                 Motor   Ano  Quilometragem  Zero_km  \
# Nome
# DS5                   Motor 2.4 Turbo  2019            0.0     True
# A5                    Motor 4.0 Turbo  2019            0.0     True
# J5                           Motor V6  2019            0.0     True
# A3                       Motor 1.0 8v  2019            0.0     True
# Série 1 M                    Motor V8  2019            0.0     True
# ...                               ...   ...            ...      ...
# Lamborghini Reventón  Motor 4.0 Turbo  2019            0.0     True
# Benni Mini                   Motor V8  2019            0.0     True
# Uno                   Motor Diesel V6  2019            0.0     True
# Santa Fe                Motor 3.0 32v  2019            0.0     True
# XC60                  Motor 4.0 Turbo  2019            0.0     True
#
#                                                              Acessórios  \
# Nome
# ...

# %%
'''isso é feito pois em Machine Learning se o valores estivessem
nulos, não seria um modelo bom pois não levaria em consideração
esse valores nulos'''
# Out:
# 'isso é feito pois em Machine Learning se o valores estivessem\nnulos, não seria um modelo bom pois não levaria em consideração\nesse valores nulos'

# %%
dataset = pd.read_csv('db.csv', sep =';')
dataset
# Out:
#                       Nome                  Motor   Ano  Quilometragem  \
# 0            Jetta Variant        Motor 4.0 Turbo  2003        44410.0
# 1                   Passat           Motor Diesel  1991         5712.0
# 2                 Crossfox        Motor Diesel V8  1990        37123.0
# 3                      DS5        Motor 2.4 Turbo  2019            NaN
# 4         Aston Martin DB4        Motor 2.4 Turbo  2006        25757.0
# ..                     ...                    ...   ...            ...
# 253           Phantom 2013               Motor V8  2014        27505.0
# 254  Cadillac Ciel concept               Motor V8  1991        29981.0
# 255             Classe GLK  Motor 5.0 V8 Bi-Turbo  2002        52637.0
# 256       Aston Martin DB5           Motor Diesel  1996         7685.0
# 257                  Macan        Motor Diesel V6  1992        50188.0
#
#      Zero_km                                         Acessórios      Valor
# ...

# %%
#caso vc queira eliminar os valor nulos, assim é feito:
dataset.dropna(subset = ['Quilometragem'], inplace = True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197 entries, 0 to 257
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Nome           197 non-null    object
#  1   Motor          197 non-null    object
#  2   Ano            197 non-null    int64
#  3   Quilometragem  197 non-null    float64
#  4   Zero_km        197 non-null    bool
#  5   Acessórios     197 non-null    object
#  6   Valor          197 non-null    float64
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 11.0+ KB
