# %% [markdown]
# # Relatório de Análise 1

# %% [markdown]
# ## Importando a Base de Dados

# %%
import pandas as pd
dados = pd.read_csv('aluguel.csv', sep=';')
dados.head()
# Out:
#           Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento               Centro        1      0       0    15   800.0
# 1  Apartamento         Higienópolis        1      0       0    48   800.0
# 2  Apartamento             Cachambi        2      0       0    50  1300.0
# 3  Apartamento               Grajaú        2      1       0    70  1500.0
# 4  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       390.0  20.0     53.33   Apartamento
# 1       230.0   0.0     16.67   Apartamento
# 2       301.0  17.0     26.00   Apartamento
# 3       642.0  74.0     21.43   Apartamento
# 4       455.0  14.0     16.67   Apartamento

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19831 entries, 0 to 19830
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           19831 non-null  object
#  1   Bairro         19831 non-null  object
#  2   Quartos        19831 non-null  int64
#  3   Vagas          19831 non-null  int64
#  4   Suites         19831 non-null  int64
#  5   Area           19831 non-null  int64
#  6   Valor          19831 non-null  float64
#  7   Condominio     19831 non-null  float64
#  8   IPTU           19831 non-null  float64
#  9   Valor m2       19831 non-null  float64
#  10  Tipo Agregado  19831 non-null  object
# dtypes: float64(4), int64(4), object(3)
# memory usage: 1.7+ MB

# %% [markdown]
# ## Informações gerais sobre a Base de Dados

# %%
#ver as variáveis e seus tipos
dados.dtypes
# Out:
# Tipo              object
# Bairro            object
# Quartos            int64
# Vagas              int64
# Suites             int64
# Area               int64
# Valor            float64
# Condominio       float64
# IPTU             float64
# Valor m2         float64
# Tipo Agregado     object
# dtype: object

# %%
tipos_dos_dados = pd.DataFrame(dados.dtypes, columns = ['Tipos dos dados'])

# %%
tipos_dos_dados.columns.name = 'Variáveis'
tipos_dos_dados
# Out:
# Variáveis     Tipos dos dados
# Tipo                   object
# Bairro                 object
# Quartos                 int64
# Vagas                   int64
# Suites                  int64
# Area                    int64
# Valor                 float64
# Condominio            float64
# IPTU                  float64
# Valor m2              float64
# Tipo Agregado          object

# %%
#ver quantidade de observações e quantidade de variáveis
dados.shape
# Out:
# (19831, 11)

# %%
print('A base de dados apresenta {} registros e {} variáveis.'.format(dados.shape[0], dados.shape[1]))
# Out:
# A base de dados apresenta 19831 registros e 11 variáveis.

# %%
json = open('aluguel.json')
print(json.read())
# Out:
# [{"Tipo":"Quitinete","Bairro":"Copacabana","Quartos":1,"Vagas":0,"Suites":0,"Area":40,"Valor":1700.0,"Condominio":500.0,"IPTU":60.0},
# {"Tipo":"Casa","Bairro":"Jardim Bot\u00e2nico","Quartos":2,"Vagas":0,"Suites":1,"Area":100,"Valor":7000.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Conjunto Comercial\/Sala","Bairro":"Barra da Tijuca","Quartos":0,"Vagas":4,"Suites":0,"Area":150,"Valor":5200.0,"Condominio":4020.0,"IPTU":1111.0},
# {"Tipo":"Apartamento","Bairro":"Centro","Quartos":1,"Vagas":0,"Suites":0,"Area":15,"Valor":800.0,"Condominio":390.0,"IPTU":20.0},
# {"Tipo":"Apartamento","Bairro":"Higien\u00f3polis","Quartos":1,"Vagas":0,"Suites":0,"Area":48,"Valor":800.0,"Condominio":230.0,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Vista Alegre","Quartos":3,"Vagas":1,"Suites":0,"Area":70,"Valor":1200.0,"Condominio":null,"IPTU":null},
# {"Tipo":"Apartamento","Bairro":"Cachambi","Quartos":2,"Vagas":0,"Suites":0,"Area":50,"Valor":1300.0,"Condominio":301.0,"IPTU":17.0},
# ...

# %%
df_json = pd.read_json('aluguel.json')
df_json
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
txt = open('aluguel.txt')
print(txt.read())
# Out:
# Tipo	Bairro	Quartos	Vagas	Suites	Area	Valor	Condominio	IPTU
# Quitinete	Copacabana	1	0	0	40	1700	500	60
# Casa	Jardim BotÃ¢nico	2	0	1	100	7000
# Conjunto Comercial/Sala	Barra da Tijuca	0	4	0	150	5200	4020	1111
# Apartamento	Centro	1	0	0	15	800	390	20
# Apartamento	HigienÃ³polis	1	0	0	48	800	230
# Apartamento	Vista Alegre	3	1	0	70	1200
# Apartamento	Cachambi	2	0	0	50	1300	301	17
# Casa de CondomÃ­nio	Barra da Tijuca	5	4	5	750	22000
# Casa de CondomÃ­nio	Ramos	2	2	0	65	1000
# Conjunto Comercial/Sala	Centro	0	3	0	695	35000	19193	3030

# %%
df_txt = pd.read_table('aluguel.txt')
df_txt
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
df_xlsx = pd.read_excel('aluguel.xlsx')
df_xlsx
# Out:
#                       Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 0                Quitinete       Copacabana        1      0       0    40
# 1                     Casa  Jardim Botânico        2      0       1   100
# 2  Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 3              Apartamento           Centro        1      0       0    15
# 4              Apartamento     Higienópolis        1      0       0    48
# 5              Apartamento     Vista Alegre        3      1       0    70
# 6              Apartamento         Cachambi        2      0       0    50
# 7       Casa de Condomínio  Barra da Tijuca        5      4       5   750
# 8       Casa de Condomínio            Ramos        2      2       0    65
# 9  Conjunto Comercial/Sala           Centro        0      3       0   695
#
#    Valor  Condominio    IPTU
# 0   1700       500.0    60.0
# 1   7000         NaN     NaN
# 2   5200      4020.0  1111.0
# 3    800       390.0    20.0
# ...

# %%
df_html = pd.read_html('dados_html_1.html')
df_html[0]
# Out:
#   FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
# 0      00 A 18               R$218,99           R$192,60    R$334,48
# 1      19 A 23               R$263,63           R$207,67    R$380,06
# 2      24 A 28               R$322,44           R$224,26    R$464,39
# 3      29 A 33               R$402,05           R$258,63    R$566,68
# 4      34 A 38               R$455,17           R$306,37    R$664,61
# 5      39 A 43               R$489,29           R$417,93    R$742,72
# 6      44 A 48               R$582,65           R$495,24    R$869,47
# 7      49 A 53               R$718,86           R$562,64  R$1.046,29
# 8      54 A 58               R$908,54           R$721,00  R$1.355,74
# 9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53

# %%
df_html = pd.read_html('file:///C:/Users/FAEST/Desktop/AulasAlura/dados_html_1.html')
df_html[0]
# Out:
#   FAIXA ETÁRIA UNAFISCO SAÚDE SOFT II SOFT PARTICIPATIVO      UNIQUE
# 0      00 A 18               R$218,99           R$192,60    R$334,48
# 1      19 A 23               R$263,63           R$207,67    R$380,06
# 2      24 A 28               R$322,44           R$224,26    R$464,39
# 3      29 A 33               R$402,05           R$258,63    R$566,68
# 4      34 A 38               R$455,17           R$306,37    R$664,61
# 5      39 A 43               R$489,29           R$417,93    R$742,72
# 6      44 A 48               R$582,65           R$495,24    R$869,47
# 7      49 A 53               R$718,86           R$562,64  R$1.046,29
# 8      54 A 58               R$908,54           R$721,00  R$1.355,74
# 9   59 OU MAIS             R$1.244,50         R$1.151,62  R$2.003,53

# %%
df_html2 = pd.read_html('file:///C:/Users/FAEST/Desktop/AulasAlura/dados_html_2.html')
len(df_html2)
# Out:
# 3

# %%
df_html2[0].head()
# Out:
#         Date      Reserve balances required                              \
#         Date Reserve balance requirements 1 Top of penalty- free band 2
# 0    Month 7                        Month 7                     Month 7
# 1  Apr. 2017                         113224                      124561
# 2   May 2017                         115464                      127023
# 3  June 2017                         118187                      130018
# 4  July 2017                         120636                      132712
#
#                                  Reserve balances maintained 4  \
#   Bottom of penalty- free band 3                         Total
# 0                        Month 7                       Month 7
# 1                         101890                       2281420
# 2                         103906                       2225769
# 3                         106357                       2206547
# 4                         108561                       2233323
#
# ...

# %%
df_html2[1].head()
# Out:
#         Date Reserves          Vault cash 2  \
#         Date  Total 1 Required        Total
# 0    Month 7  Month 7  Month 7      Month 7
# 1  Apr. 2017  2344812   176616        74055
# 2   May 2017  2288936   178630        72954
# 3  June 2017  2269683   181324        72881
# 4  July 2017  2296929   184242        73572
#
#                                                 Monetary base  \
#   Used to satisfy required reserves 3 Surplus 4       Total 5
# 0                             Month 7   Month 7       Month 7
# 1                               63392     10663       3821697
# 2                               63167      9787       3774412
# 3                               63137      9745       3762780
# 4                               63606      9966       3795430
#
#
#   Total balances maintained 6 Currency in circulation
# 0                     Month 7                 Month 7
# 1                     2281420                 1540277
# ...

# %%
df_html2[2].head()
# Out:
#         Date Borrowings from the Federal Reserve                              \
#         Date                               Total  Primary Secondary Seasonal
# 0    Month 2                             Month 2  Month 2   Month 2  Month 2
# 1  Apr. 2017                                  45       21         0       24
# 2   May 2017                                  56       11         0       44
# 3  June 2017                                  95       15         0       80
# 4  July 2017                                 166       12         0      154
#
#                           Nonborrowed reserves 1
#   Other credit extensions Nonborrowed reserves 1
# 0                 Month 2                Month 2
# 1                       0                2344767
# 2                       0                2288880
# 3                       0                2269588
# 4                       0                2296763

# %% [markdown]
# # Relatório de Análise 2

# %% [markdown]
# ## Tipos de Imóveis

# %%
import pandas as pd
dados = pd.read_csv('aluguel.csv', sep=';')
dados.head(10)
# Out:
#           Tipo                   Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento                   Centro        1      0       0    15   800.0
# 1  Apartamento             Higienópolis        1      0       0    48   800.0
# 2  Apartamento                 Cachambi        2      0       0    50  1300.0
# 3  Apartamento                   Grajaú        2      1       0    70  1500.0
# 4  Apartamento      Lins de Vasconcelos        3      1       1    90  1500.0
# 5  Apartamento               Copacabana        1      0       1    40  2000.0
# 6  Apartamento  Freguesia (Jacarepaguá)        3      0       0    54   950.0
# 7  Apartamento          Barra da Tijuca        2      1       1    67  1700.0
# 8  Apartamento                   Tijuca        2      1       0   110  1900.0
# 9  Apartamento                   Olaria        3      1       0    68  1000.0
#
#    Condominio   IPTU  Valor m2 Tipo Agregado
# 0       390.0   20.0     53.33   Apartamento
# ...

# %%
dados['Tipo']
# Out:
# 0        Apartamento
# 1        Apartamento
# 2        Apartamento
# 3        Apartamento
# 4        Apartamento
#             ...
# 19826      Quitinete
# 19827      Quitinete
# 19828      Quitinete
# 19829      Quitinete
# 19830      Quitinete
# Name: Tipo, Length: 19831, dtype: object

# %%
tipo_de_imovel = dados['Tipo']
type(tipo_de_imovel)
# Out:
# pandas.core.series.Series

# %%
#identificar cada tipo de imovel na series

tipo_de_imovel.drop_duplicates(inplace = True)
tipo_de_imovel
# Out:
# 0               Apartamento
# 16923                  Casa
# 17821    Casa de Condomínio
# 18785          Casa de Vila
# 19018             Quitinete
# Name: Tipo, dtype: object

# %% [markdown]
# ## Organizando a visualização

# %%
tipo_de_imovel = pd.DataFrame(tipo_de_imovel)
tipo_de_imovel
# Out:
#                      Tipo
# 0             Apartamento
# 16923                Casa
# 17821  Casa de Condomínio
# 18785        Casa de Vila
# 19018           Quitinete

# %%
#mudar o index

tipo_de_imovel.index
tipo_de_imovel.shape[0]
range(tipo_de_imovel.shape[0])
tipo_de_imovel.index = range(tipo_de_imovel.shape[0])

# %%
tipo_de_imovel.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
tipo_de_imovel
# Out:
#                  Tipo
# 0         Apartamento
# 1                Casa
# 2  Casa de Condomínio
# 3        Casa de Vila
# 4           Quitinete

# %%
tipo_de_imovel.columns.name='Id'
tipo_de_imovel
# Out:
# Id                Tipo
# 0          Apartamento
# 1                 Casa
# 2   Casa de Condomínio
# 3         Casa de Vila
# 4            Quitinete

# %% [markdown]
# # Series

# %%
data = [1,2,3,4,5]

# %%
s = pd.Series(data)
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
#1° forma de botar um rótulo no index
index = ['linha' + str(i) for i in range(5)]

# %%
index
# Out:
# ['linha0', 'linha1', 'linha2', 'linha3', 'linha4']

# %%
s = pd.Series(data= data, index= index)
s
# Out:
# linha0    1
# linha1    2
# linha2    3
# linha3    4
# linha4    5
# dtype: int64

# %% [markdown]
# ## DataFrame

# %%
data = [[1,2,3], [4,5,6], [7,8,9]]
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
df1 = pd.DataFrame(data)
df1
# Out:
#    0  1  2
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
index = ['Linha' + str(i) for i in range(3)]
index
# Out:
# ['Linha0', 'Linha1', 'Linha2']

# %%
df1 = pd.DataFrame(data, index)
df1
# Out:
#         0  1  2
# Linha0  1  2  3
# Linha1  4  5  6
# Linha2  7  8  9

# %%
columns = ['Coluna' + str(i) for i in range(3)]
columns
# Out:
# ['Coluna0', 'Coluna1', 'Coluna2']

# %%
df1 = pd.DataFrame(data, index, columns)
df1
# Out:
#         Coluna0  Coluna1  Coluna2
# Linha0        1        2        3
# Linha1        4        5        6
# Linha2        7        8        9

# %%
df2 = pd.DataFrame(data)
index = ['Linha' + str(i) for i in range(3)]
columns = ['Coluna' + str(i) for i in range(3)]
df2 = pd.DataFrame(data, index, columns)
df2[df2 > 0] = 'A'
df2
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       A       A       A
# Linha1       A       A       A
# Linha2       A       A       A

# %%
df3 = pd.concat([df1, df2])
df3
# Out:
#        Coluna0 Coluna1 Coluna2
# Linha0       1       2       3
# Linha1       4       5       6
# Linha2       7       8       9
# Linha0       A       A       A
# Linha1       A       A       A
# Linha2       A       A       A

# %%
df3 = pd.concat([df1, df2], axis = 1)
df3
# Out:
#        Coluna0 Coluna1 Coluna2 Coluna0 Coluna1 Coluna2
# Linha0       1       2       3       A       A       A
# Linha1       4       5       6       A       A       A
# Linha2       7       8       9       A       A       A

# %% [markdown]
# # Relatórios de Análise 3

# %% [markdown]
# ## Selecionando somente os imoveis residenciais de um DF

# %%
dados.head()
# Out:
#           Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0  Apartamento               Centro        1      0       0    15   800.0
# 1  Apartamento         Higienópolis        1      0       0    48   800.0
# 2  Apartamento             Cachambi        2      0       0    50  1300.0
# 3  Apartamento               Grajaú        2      1       0    70  1500.0
# 4  Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
#
#    Condominio  IPTU  Valor m2 Tipo Agregado
# 0       390.0  20.0     53.33   Apartamento
# 1       230.0   0.0     16.67   Apartamento
# 2       301.0  17.0     26.00   Apartamento
# 3       642.0  74.0     21.43   Apartamento
# 4       455.0  14.0     16.67   Apartamento

# %%
list(dados['Tipo'].drop_duplicates())
# Out:
# ['Apartamento', 'Casa', 'Casa de Condomínio', 'Casa de Vila', 'Quitinete']

# %%
casas = ['Casa', 'Casa de Condomínio', 'Casa de Vila']
casas
# Out:
# ['Casa', 'Casa de Condomínio', 'Casa de Vila']

# %%
selecionados = dados['Tipo'].isin(casas)
selecionados.index = range(selecionados.shape[0])
selecionados
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# Name: Tipo, dtype: bool

# %%
dados_casa = dados
list(dados_casa['Tipo'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-158-5194b9561290> in <module>
# ----> 1 dados_casa = dados.selecionados
#       2 list(dados_casa['Tipo'])
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'selecionados'

# %% [markdown]
# ## Exportando base de dados

# %%
dados.to_csv('teste.csv', sep=';')

# %%
mesmo_dado = pd.read_csv('teste.csv', sep=';')
mesmo_dado
# Out:
#        Unnamed: 0         Tipo               Bairro  Quartos  Vagas  Suites  \
# 0               0  Apartamento               Centro        1      0       0
# 1               1  Apartamento         Higienópolis        1      0       0
# 2               2  Apartamento             Cachambi        2      0       0
# 3               3  Apartamento               Grajaú        2      1       0
# 4               4  Apartamento  Lins de Vasconcelos        3      1       1
# ...           ...          ...                  ...      ...    ...     ...
# 19826       19826    Quitinete               Glória        1      0       0
# 19827       19827    Quitinete             Flamengo        1      0       0
# 19828       19828    Quitinete               Centro        1      0       0
# 19829       19829    Quitinete           Copacabana        1      0       0
# 19830       19830    Quitinete               Centro        0      0       0
#
# ...

# %%
#removendo o indice para que quando formos abrir de novo, não
#duplique os índices

dados.to_csv('teste.csv', sep=';', index=False)

# %%
mesmo_dado = pd.read_csv('teste.csv', sep=';')
mesmo_dado
# Out:
#               Tipo               Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0      Apartamento               Centro        1      0       0    15   800.0
# 1      Apartamento         Higienópolis        1      0       0    48   800.0
# 2      Apartamento             Cachambi        2      0       0    50  1300.0
# 3      Apartamento               Grajaú        2      1       0    70  1500.0
# 4      Apartamento  Lins de Vasconcelos        3      1       1    90  1500.0
# ...            ...                  ...      ...    ...     ...   ...     ...
# 19826    Quitinete               Glória        1      0       0    10   400.0
# 19827    Quitinete             Flamengo        1      0       0    23   900.0
# 19828    Quitinete               Centro        1      0       0    24  1100.0
# 19829    Quitinete           Copacabana        1      0       0    22  1500.0
# 19830    Quitinete               Centro        0      0       0    27   800.0
#
# ...

# %% [markdown]
# ## Organizando DataFrames (Sort)

# %%
import pandas as pd
data = [[1,2,3], [4,5,6], [7,8,9]]
data
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
list('321')
# Out:
# ['3', '2', '1']

# %%
df = pd.DataFrame(data, list('321'), list('cba'))
df
# Out:
#    c  b  a
# 3  1  2  3
# 2  4  5  6
# 1  7  8  9

# %%
df.sort_index(inplace = True)
df
# Out:
#    c  b  a
# 1  7  8  9
# 2  4  5  6
# 3  1  2  3

# %%
df.sort_index(inplace = True, axis = 1)
df
# Out:
#    a  b  c
# 1  9  8  7
# 2  6  5  4
# 3  3  2  1

# %%
df.sort_values(by = '3', axis = 1, inplace = True)
df
# Out:
#    c  b  a
# 3  1  2  3
# 2  4  5  6
# 1  7  8  9
