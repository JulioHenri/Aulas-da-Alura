# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
import seaborn as sns

# %%
dados = pd.read_csv('tips.csv')
dados.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %% [markdown]
# # Tradução

# %%
dados.columns=['valor_da_conta','gorjeta','sobremesa','dia',
               'hora_do_dia','total_de_pessoas']
dados.head()
# Out:
#    valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas
# 0           16.99     1.01        No  Sun      Dinner                 2
# 1           10.34     1.66        No  Sun      Dinner                 3
# 2           21.01     3.50        No  Sun      Dinner                 3
# 3           23.68     3.31        No  Sun      Dinner                 2
# 4           24.59     3.61        No  Sun      Dinner                 4

# %%
dados.sobremesa.replace(['No','Yes'],['Não','Sim'],inplace=True)
dados.dia.replace(['Sun', 'Sat', 'Thur', 'Fri'],['Dom','Sab','Qui','Sex'],inplace=True)
dados.hora_do_dia.replace(['Dinner', 'Lunch'],['Jantar','Almoço'],inplace=True)

# %%
dados.head()
# Out:
#    valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas
# 0           16.99     1.01       Não  Dom      Jantar                 2
# 1           10.34     1.66       Não  Dom      Jantar                 3
# 2           21.01     3.50       Não  Dom      Jantar                 3
# 3           23.68     3.31       Não  Dom      Jantar                 2
# 4           24.59     3.61       Não  Dom      Jantar                 4

# %% [markdown]
# # Análise 1 - Valor da conta e gorjeta

# %%
ax = sns.scatterplot(x='valor_da_conta',y='gorjeta',data=dados)
ax.set_title('Gráfico de dispersão valor da conta X gorjeta', fontsize=14)
ax
#A gorjeta aumenta conforme aumenta o valor da conta

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   valor_da_conta    244 non-null    float64
#  1   gorjeta           244 non-null    float64
#  2   sobremesa         244 non-null    object
#  3   dia               244 non-null    object
#  4   hora_do_dia       244 non-null    object
#  5   total_de_pessoas  244 non-null    int64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 11.6+ KB

# %% [markdown]
# ## Criando nova coluna

# %%
dados['porcentagem_gorjeta'] = (dados.gorjeta / dados.valor_da_conta).round(2)
dados.head()
# Out:
#    valor_da_conta  gorjeta sobremesa  dia hora_do_dia  total_de_pessoas  \
# 0           16.99     1.01       Não  Dom      Jantar                 2
# 1           10.34     1.66       Não  Dom      Jantar                 3
# 2           21.01     3.50       Não  Dom      Jantar                 3
# 3           23.68     3.31       Não  Dom      Jantar                 2
# 4           24.59     3.61       Não  Dom      Jantar                 4
#
#    porcentagem_gorjeta
# 0                 0.06
# 1                 0.16
# 2                 0.17
# 3                 0.14
# 4                 0.15

# %%
ax = sns.scatterplot(x='valor_da_conta',y='porcentagem_gorjeta',data=dados)

#Visualmente percebe-se que o valor da conta não é proporcional ao
#ao valor da gorjeta

# %%
sns.relplot(x='valor_da_conta',y='porcentagem_gorjeta',data=dados,kind='line')

# %%
sns.lmplot(x='valor_da_conta',y='porcentagem_gorjeta',data=dados)

# %%
ax.get_figure()
ax.set_title('valor da conta X gorjeta')
ax.get_figure()

# %% [markdown]
# # Análise 2 - Sobremesa

# %%
dados[dados.sobremesa=='Sim'].describe()
# Out:
#        valor_da_conta    gorjeta  total_de_pessoas  porcentagem_gorjeta
# count       93.000000  93.000000         93.000000            93.000000
# mean        20.756344   3.008710          2.408602             0.163226
# std          9.832154   1.401468          0.810751             0.085060
# min          3.070000   1.000000          1.000000             0.040000
# 25%         13.420000   2.000000          2.000000             0.110000
# 50%         17.920000   3.000000          2.000000             0.150000
# 75%         26.860000   3.680000          3.000000             0.200000
# max         50.810000  10.000000          5.000000             0.710000

# %%
dados[dados.sobremesa=='Não'].describe()
# Out:
#        valor_da_conta     gorjeta  total_de_pessoas  porcentagem_gorjeta
# count      151.000000  151.000000        151.000000           151.000000
# mean        19.188278    2.991854          2.668874             0.159536
# std          8.255582    1.377190          1.017984             0.039889
# min          7.250000    1.000000          1.000000             0.060000
# 25%         13.325000    2.000000          2.000000             0.140000
# 50%         17.590000    2.740000          2.000000             0.160000
# 75%         22.755000    3.505000          3.000000             0.185000
# max         48.330000    9.000000          6.000000             0.290000

# %%
ax = sns.catplot(x='sobremesa',y='gorjeta',data=dados)

# %%
sns.relplot(x='valor_da_conta',y='gorjeta',data=dados,hue='sobremesa')

# %%
sns.relplot(x='valor_da_conta',y='gorjeta',data=dados,hue='sobremesa',col='sobremesa')

# %%
sns.lmplot(x='valor_da_conta',y='gorjeta',data=dados,hue='sobremesa',col='sobremesa')

# %%
sns.lmplot(x='valor_da_conta',y='porcentagem_gorjeta',data=dados,hue='sobremesa',col='sobremesa')

# %%
#Visualmente existe diferente na gorjeta dos que pediram sobremesa
#e dos que não pediram

# %%
sns.relplot(x='valor_da_conta',y='gorjeta',data=dados,hue='sobremesa',col='sobremesa',kind='line')

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# H<sup>nula</sup> = A distribuição da taxa de gorjeta é a mesma entre os que pediram sobremesa e que não pediram
#
# H<sup>alt</sup> =A distribuição da taxa de gorjeta não é a mesma entre os que pediram sobremesa e que não pediram

# %%
from scipy.stats import ranksums

# %%
sobremesa = dados.query('sobremesa=="Sim"').porcentagem_gorjeta
sem_sobremesa = dados.query('sobremesa=="Não"').porcentagem_gorjeta

# %%
pvalue = ranksums(sobremesa, sem_sobremesa)

# %% [markdown]
# **Como o p-value é maior que 0.05, então aceitamos a hipótese nula. Logo, a distribuição entre os dois grupos é a mesma**

# %%
print('O valor do p-value é {}'.format(pvalue[1]))
# Out:
# O valor do p-value é 0.5266635660124415

# %% [markdown]
# # Análise 3 - Dias da Semana

# %%
dados.dia.unique()
# Out:
# array(['Dom', 'Sab', 'Qui', 'Sex'], dtype=object)

# %%
sns.catplot(x='dia',y='valor_da_conta',data=dados)

# %%
sns.relplot(x='valor_da_conta',y='gorjeta',
            hue='dia',data=dados,col='dia')

# %%
sns.lmplot(x='valor_da_conta',y='gorjeta',
            hue='dia',data=dados,col='dia')

# %%
media_gorjeta = dados.gorjeta.mean()
print('A média geral das gorjetas é de {:.2f}'.format(media_gorjeta))
# Out:
# A média geral das gorjetas é de 3.00

# %%
dados.groupby(['dia']).mean()[['valor_da_conta','gorjeta','porcentagem_gorjeta']]
# Out:
#      valor_da_conta   gorjeta  porcentagem_gorjeta
# dia
# Dom       21.410000  3.255132             0.166974
# Qui       17.682742  2.771452             0.161129
# Sab       20.441379  2.993103             0.153678
# Sex       17.151579  2.734737             0.169474

# %%
print('Frequência dos dias')
dados.dia.value_counts()
# Out:
# Frequência dos dias
# Sab    87
# Dom    76
# Qui    62
# Sex    19
# Name: dia, dtype: int64

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# H<sup>nula</sup> = A distribuição do valor da conta é igual no sábado e no domingo </b>
# H<sup>alt</sup> = A distribuição do valor da conta é não é igual no sábado e no domingo

# %%
valor_conta_dom = dados.query('dia == "Dom"').valor_da_conta
valor_conta_sab = dados.query('dia == "Sab"').valor_da_conta

# %%
ranksums(valor_conta_dom,valor_conta_sab)
# Out:
# RanksumsResult(statistic=0.9198084864360142, pvalue=0.3576728477868443)

# %% [markdown]
# Como o p-value é maior do que 0.05, aceitamos a hipótese nula. Logo, a distribuição do valor da conta é estatisticamente
# igual no sábado e no domingo

# %% [markdown]
# # Análise 4 - Hora do dia

# %%
dados.hora_do_dia.unique()
# Out:
# array(['Jantar', 'Almoço'], dtype=object)

# %%
sns.catplot(x='hora_do_dia',y='valor_da_conta',data=dados)

# %%
sns.catplot(x='hora_do_dia',y='valor_da_conta',data=dados,kind='swarm')

# %%
sns.violinplot(x='hora_do_dia',y='valor_da_conta',data=dados)

# %%
sns.boxplot(x='hora_do_dia',y='valor_da_conta',data=dados)

# %%
almoço = dados.query('hora_do_dia=="Almoço"').valor_da_conta

# %%
sns.distplot(almoço)

# %%
sns.distplot(almoço,kde=False)

# %%
jantar = dados.query('hora_do_dia=="Jantar"').valor_da_conta

# %%
sns.distplot(jantar)

# %%
dados.groupby(['hora_do_dia']).mean()[['valor_da_conta','gorjeta','porcentagem_gorjeta']]
# Out:
#              valor_da_conta   gorjeta  porcentagem_gorjeta
# hora_do_dia
# Almoço            17.168676  2.728088             0.163971
# Jantar            20.797159  3.102670             0.159773

# %% [markdown]
# ## Teste de hipótese

# %% [markdown]
# H<sup>nula</sup> = A distribuição do valor da conta é a mesma entre o jantar e o almoço
#
# H<sup>alt</sup> = A distribuição do valor da conta não é a mesma entre o jantar e o almoço

# %%
ranksums(jantar,almoço)
# Out:
# RanksumsResult(statistic=3.2438872807262955, pvalue=0.0011791039723641672)

# %%
#Ou seja, como pvalue < 0.05, rejeitamos a hipótese nula que a 
#distribuição do valor da conta entre janta e almoço não é a mesma
